# %% [markdown]
# # Librairies nécessaires

# %%
import commentjson
import os
#os.chdir('/mnt/batch/tasks/shared/LS_root/mounts/clusters/pythonnb/code/Users/david.mouquet/modeling')


import missingno as msno
import sys
import importlib
import pandas as pd
import math
import datetime
import numpy as np

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import feature_column

sys.path.append("../SRC/")
import Utilitaires as utils
importlib.reload(utils)
import RapportModelisation as modelreport
import importFromUV as preprocdata
importlib.reload(preprocdata)
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Lecture des données

# %%
file_model_param   = "models_param/TCC-DK-Elec.json"

model_id           = "R1V1_Conso_electricite_En_Charge_ref_2019_V2"
site               = "DK-TCC"

###############################################################

with open(file_model_param, encoding='utf-8') as file:
    dico_model_all = commentjson.load(file)

dico_model = dico_model_all[model_id]



#pkl_model_name      = "resu/models/"+model_id+"_"+ dico_model['type_model'] + "_" +dico_model['freq']+".pkl"

onnx_model_name     = dico_model['mangling']+"."+model_id+".onnx"
nom_model_registre  = dico_model['nom_model_registre']
freq                = dico_model['freq']
uv_mangling         = dico_model['mangling']
nom_data_store      = dico_model['data_store']


ref_periode_debut = datetime.datetime.strptime(dico_model['ref_periode_debut'], '%d/%m/%Y %H:%M:%S').isoformat()
ref_periode_fin   = datetime.datetime.strptime(dico_model['ref_periode_fin'], '%d/%m/%Y %H:%M:%S').isoformat()


data, clean_report = preprocdata.Charger_Preparer_Data(ref_periode_debut = ref_periode_debut, 
                                         ref_periode_fin   = ref_periode_fin,
                                         ipe_tag           = dico_model["tag_modelise"],
                                         dico_du_model     = dico_model,
                                         use_seuil_min     = True,
                                         use_seuil_max     = True,
                                         clean_data        = False,
                                         concat_after      = True,
                                         load_unused_feature = True,
                                         zscore            = 3)
# Out:
# import du tag: tag_4278
# import du tag: tag_10260
# import du tag: tag_10261
# import du tag: tag_35633
# import du tag: tag_3931
# import du tag: tag_9323
# import du tag: tag_3928
# import du tag: tag_3359

# %%
data.describe()
# Out:
#        DK_TCC_Laminoir_R1V1_IPE_ELEC_EN_CHARGE_kWh_BOB  \
# count                                    157161.000000
# mean                                         45.847040
# std                                          14.981270
# min                                           6.385385
# 25%                                          34.392022
# 50%                                          45.430984
# 75%                                          56.563919
# max                                         105.832936
#
#        R1V1_Taux_reduction_epaisseur  R1V1_Refoulement  \
# count                  157161.000000     157161.000000
# mean                       23.413113        101.671245
# std                         2.165151         72.970507
# min                         8.496719          0.000000
# 25%                        21.004028         34.971924
# 50%                        24.316536         99.221436
# 75%                        24.808295        163.442993
# max                        28.977343        301.874573
#
#        Tps_Entree_TCC_Sortie_R1V1  LARG_BRAME_THEOR  teta_moy_v1r1  \
# count               157161.000000     157161.000000  157161.000000
# mean                    71.524917       1348.975099    1198.351839
# std                     15.172197        196.331746      17.829024
# min                     22.248928        750.000000    1100.061279
# 25%                     72.882462       1190.000000    1186.693481
# 50%                     76.252317       1340.000000    1198.140381
# 75%                     78.468355       1490.000000    1209.923096
# max                    130.710380       1922.447144    1293.523804
#
#        Longueur_Brame
# count    157161.00000
# mean          8.52407
# std           1.18223
# min           5.21000
# 25%           7.88500
# 50%           8.88500
# 75%           9.50500
# max           9.85000

# %% [markdown]
# # Coefficient de corrélation

# %%
df_num_corr = utils.Compute_Corr_Coef(data=data, dico_model =dico_model)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Découpage des données en train et test

# %%
data = data.dropna()

# %%
train_dataset, test_dataset = train_test_split(data, test_size=0.25)

train_labels = train_dataset.pop(dico_model["tag_name"])
test_labels  = test_dataset.pop(dico_model["tag_name"])

# %% [markdown]
# ### transformation en tensors

# %%
def df_to_dataset(df_features, df_label, shuffle=True, batch_size=32):
  ds = tf.data.Dataset.from_tensor_slices((dict(df_features), df_label))
  if shuffle:
    ds = ds.shuffle(buffer_size=len(df_features))
  ds = ds.batch(batch_size)
  return ds

# %%
train_dataset_ts = df_to_dataset(train_dataset,train_labels)
test_dataset_ts  = df_to_dataset(test_dataset,test_labels)

# %%
train_features = tf.convert_to_tensor(train_dataset, dtype=tf.float32)

# %%
train_features
# Out:
# <tf.Tensor: shape=(117870, 7), dtype=float32, numpy=
# array([[  20.932,    0.   ,   31.236, ..., 1201.834,    9.185,   61.   ],
#        [  20.461,  170.647,   75.365, ..., 1206.751,    8.535,    1.   ],
#        [  26.383,  105.998,   74.992, ..., 1174.347,    6.005,   33.   ],
#        ...,
#        [  25.557,   85.338,   79.094, ..., 1190.798,    9.775,    4.   ],
#        [  24.268,  145.757,   77.817, ..., 1180.856,    8.865,   40.   ],
#        [  24.373,  178.483,   76.34 , ..., 1171.52 ,    9.085,   33.   ]],
#       dtype=float32)>

# %% [markdown]
# ### Normalisation des facteurs numériques

# %%
def get_scal(feature):
  def minmax(x):
    mini = train_dataset[feature].min()
    maxi = train_dataset[feature].max()
    return (x - mini)/(maxi-mini)
  return(minmax)

# %%
num_c = [name for name, column in train_dataset.items() if  column.dtype == np.float64]
cat_c = [name for name, column in train_dataset.items() if  column.dtype == object]

# %%
feature_columns = []
for header in num_c:
  scal_input_fn = get_scal(header)
  feature_columns.append(feature_column.numeric_column(header, normalizer_fn=scal_input_fn))

# %%
feature_columns
# Out:
# [NumericColumn(key='R1V1_Taux_reduction_epaisseur', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_scal.<locals>.minmax at 0x000001F9E246A5E0>),
#  NumericColumn(key='R1V1_Refoulement', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_scal.<locals>.minmax at 0x000001F9E246A790>),
#  NumericColumn(key='Tps_Entree_TCC_Sortie_R1V1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_scal.<locals>.minmax at 0x000001F9E246A550>),
#  NumericColumn(key='LARG_BRAME_THEOR', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_scal.<locals>.minmax at 0x000001F9E246A820>),
#  NumericColumn(key='teta_moy_v1r1', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_scal.<locals>.minmax at 0x000001F9E246A8B0>),
#  NumericColumn(key='Longueur_Brame', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_scal.<locals>.minmax at 0x000001F9E246A940>)]

# %% [markdown]
# ### Encodage des variables catégorielles

# %%
for feature_name in cat_c:
  vocabulary = data[feature_name].unique()
  col_cat = tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary)
  one_hot = feature_column.indicator_column(col_cat)
  feature_columns.append(one_hot)

# %%
feature_layer = tf.keras.layers.DenseFeatures(feature_columns)

# %%
model= tf.keras.Sequential([feature_layer,layers.Dense(64, activation='relu'),layers.Dense(1)],name = 'target')


model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# %%
features_dict = {name: np.array(value) 
                         for name, value in train_dataset.items()}
features_dict_test = {name: np.array(value) 
                         for name, value in test_features.items()}

# %%
train_dataset_ts
# Out:
# <BatchDataset element_spec=({'R1V1_Taux_reduction_epaisseur': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'R1V1_Refoulement': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'Tps_Entree_TCC_Sortie_R1V1': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'LARG_BRAME_THEOR': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'teta_moy_v1r1': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'Longueur_Brame': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'Code_Metal': TensorSpec(shape=(None,), dtype=tf.string, name=None)}, TensorSpec(shape=(None,), dtype=tf.float64, name=None))>

# %%
#history = model.fit(x=(train_dataset_ts,train_labels), epochs=20,validation_data=(test_dataset_ts,test_labels))

#history = model.fit(x=features_dict, y=train_labels, epochs=20,validation_data=(features_dict_test,test_labels))


history = model.fit(train_dataset_ts, epochs=20,validation_data=test_dataset_ts)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'R1V1_Taux_reduction_epaisseur': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=float64>, 'R1V1_Refoulement': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=float64>, 'Tps_Entree_TCC_Sortie_R1V1': <tf.Tensor 'IteratorGetNext:5' shape=(None,) dtype=float64>, 'LARG_BRAME_THEOR': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=float64>, 'teta_moy_v1r1': <tf.Tensor 'IteratorGetNext:6' shape=(None,) dtype=float64>, 'Longueur_Brame': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=float64>, 'Code_Metal': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'R1V1_Taux_reduction_epaisseur': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=float64>, 'R1V1_Refoulement': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=float64>, 'Tps_Entree_TCC_Sortie_R1V1': <tf.Tensor 'IteratorGetNext:5' shape=(None,) dtype=float64>, 'LARG_BRAME_THEOR': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=float64>, 'teta_moy_v1r1': <tf.Tensor 'IteratorGetNext:6' shape=(None,) dtype=float64>, 'Longueur_Brame': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=float64>, 'Code_Metal': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# 3670/3684 [============================>.] - ETA: 0s - loss: 7.5622WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'R1V1_Taux_reduction_epaisseur': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=float64>, 'R1V1_Refoulement': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=float64>, 'Tps_Entree_TCC_Sortie_R1V1': <tf.Tensor 'IteratorGetNext:5' shape=(None,) dtype=float64>, 'LARG_BRAME_THEOR': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=float64>, 'teta_moy_v1r1': <tf.Tensor 'IteratorGetNext:6' shape=(None,) dtype=float64>, 'Longueur_Brame': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=float64>, 'Code_Metal': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# 3684/3684 [==============================] - 8s 2ms/step - loss: 7.5502 - val_loss: 3.9500
# Epoch 2/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 3.7017 - val_loss: 3.4962
# Epoch 3/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 3.4034 - val_loss: 3.2780
# Epoch 4/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 3.2234 - val_loss: 3.1571
# Epoch 5/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 3.1127 - val_loss: 3.0540
# Epoch 6/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 3.0500 - val_loss: 3.0517
# Epoch 7/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 3.0137 - val_loss: 2.9794
# Epoch 8/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9871 - val_loss: 2.9811
# Epoch 9/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9727 - val_loss: 2.9715
# Epoch 10/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9577 - val_loss: 2.9400
# Epoch 11/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9465 - val_loss: 2.9560
# Epoch 12/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9374 - val_loss: 2.9267
# Epoch 13/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9299 - val_loss: 2.9191
# Epoch 14/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9249 - val_loss: 2.9110
# Epoch 15/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9155 - val_loss: 2.9000
# Epoch 16/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9116 - val_loss: 2.9102
# Epoch 17/20
# 3684/3684 [==============================] - 8s 2ms/step - loss: 2.9067 - val_loss: 2.8979
# Epoch 18/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9025 - val_loss: 2.8857
# Epoch 19/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.9008 - val_loss: 2.8971
# Epoch 20/20
# 3684/3684 [==============================] - 7s 2ms/step - loss: 2.8936 - val_loss: 2.8866

# %% [markdown]
# # Apprentissage

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
# %tensorboard --logdir logs/fit

# %% [markdown]
# # Performance globale

# %%
features_dict = {name: np.array(value) 
                         for name, value in train_dataset.items()}
features_dict_test = {name: np.array(value) 
                         for name, value in test_dataset.items()}


train_predictions = model.predict(features_dict).flatten()
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'R1V1_Taux_reduction_epaisseur': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=float32>, 'R1V1_Refoulement': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=float32>, 'Tps_Entree_TCC_Sortie_R1V1': <tf.Tensor 'IteratorGetNext:5' shape=(None,) dtype=float32>, 'LARG_BRAME_THEOR': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=float32>, 'teta_moy_v1r1': <tf.Tensor 'IteratorGetNext:6' shape=(None,) dtype=float32>, 'Longueur_Brame': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=float32>, 'Code_Metal': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# 3684/3684 [==============================] - 5s 1ms/step

# %%
test_predictions = model.predict(features_dict_test).flatten()
# Out:
# 1228/1228 [==============================] - 2s 1ms/step

# %%
r2_score(test_labels.values,test_predictions)
# Out:
# 0.9135498748543753

# %%
print(r2_score(train_labels.values,train_predictions),r2_score(test_labels.values,test_predictions))
# Out:
# 0.9136158416204834 0.9135498748543753

# %%
df_prediction = pd.Series(index=data.index,data=pred_label)

# %%
import plotly.graph_objects as go


# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_prediction.index, y=df_prediction,
                    mode='lines',
                    name='Modele'))
fig.add_trace(go.Scatter(x=true_labels.index, y=true_labels,
                    mode='lines',
                    name='Mesure'))

#fig.update_layout(title='Four n° ' + N_Four + ' Durée entre défournement et prochain enfournement',
#                   xaxis_title='Date',
#                   yaxis_title='minutes')
fig.show()

# %% [markdown]
# # Export vers ONNX

# %%
importlib.reload(modelreport)

model_type = "réseau de neuronnes"

modelreport_json = modelreport.BuildModelReport(model_type  = model_type,
                                                ref_periode_debut  = datetime.datetime.strftime(data.index[0], '%Y-%m-%d %H:%M:%S')  ,
                                                ref_periode_fin= datetime.datetime.strftime(data.index[-1], '%Y-%m-%d %H:%M:%S'),
                                                clean_report = clean_report,
                                                description = '',
                                                test_data_set = test_data_set,
                                                train_data_set = train_data_set,
                                                fitted_model = fitted_model,
                                                df_num_corr = df_num_corr,
                                                dico_model = dico_model,
                                                data = data)
# Out:
# 'target'

# %%
import tf2onnx
(onnx_model_proto, storage) = tf2onnx.convert.from_keras(model)
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'DK_TCC_Laminoir_R1V1_IPE_ELEC_EN_CHARGE_kWh_BOB': <tf.Tensor 'DK_TCC_Laminoir_R1V1_IPE_ELEC_EN_CHARGE_kWh_BOB:0' shape=(None,) dtype=float32>, 'R1V1_Taux_reduction_epaisseur': <tf.Tensor 'R1V1_Taux_reduction_epaisseur:0' shape=(None,) dtype=float32>, 'R1V1_Refoulement': <tf.Tensor 'R1V1_Refoulement:0' shape=(None,) dtype=float32>, 'Tps_Entree_TCC_Sortie_R1V1': <tf.Tensor 'Tps_Entree_TCC_Sortie_R1V1:0' shape=(None,) dtype=float32>, 'LARG_BRAME_THEOR': <tf.Tensor 'LARG_BRAME_THEOR:0' shape=(None,) dtype=float32>, 'teta_moy_v1r1': <tf.Tensor 'teta_moy_v1r1:0' shape=(None,) dtype=float32>, 'Longueur_Brame': <tf.Tensor 'Longueur_Brame:0' shape=(None,) dtype=float32>, 'Code_Metal': <tf.Tensor 'Code_Metal:0' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# Cannot infer shape for target/dense_features_2/Code_Metal_embedding/None_Lookup/LookupTableFindV2: target/dense_features_2/Code_Metal_embedding/None_Lookup/LookupTableFindV2:0
# Cannot infer shape for target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GreaterEqual: target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GreaterEqual:0
# Cannot infer shape for target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_2: target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_2:0

# %%
onnx_model_proto.metadata_props
# Out:
# []

# %%
import tensorflow as tf
import tf2onnx
#model.layers[-1]._name = 'target'
# model.save('model_ts')
# model = tf.keras.models.load_model('model_ts')

tf2onnx.convert.from_keras(model, output_path='model_R1V1_ts_test.onnx')
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'DK_TCC_Laminoir_R1V1_IPE_ELEC_EN_CHARGE_kWh_BOB': <tf.Tensor 'DK_TCC_Laminoir_R1V1_IPE_ELEC_EN_CHARGE_kWh_BOB:0' shape=(None,) dtype=float32>, 'R1V1_Taux_reduction_epaisseur': <tf.Tensor 'R1V1_Taux_reduction_epaisseur:0' shape=(None,) dtype=float32>, 'R1V1_Refoulement': <tf.Tensor 'R1V1_Refoulement:0' shape=(None,) dtype=float32>, 'Tps_Entree_TCC_Sortie_R1V1': <tf.Tensor 'Tps_Entree_TCC_Sortie_R1V1:0' shape=(None,) dtype=float32>, 'LARG_BRAME_THEOR': <tf.Tensor 'LARG_BRAME_THEOR:0' shape=(None,) dtype=float32>, 'teta_moy_v1r1': <tf.Tensor 'teta_moy_v1r1:0' shape=(None,) dtype=float32>, 'Longueur_Brame': <tf.Tensor 'Longueur_Brame:0' shape=(None,) dtype=float32>, 'Code_Metal': <tf.Tensor 'Code_Metal:0' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# Cannot infer shape for target/dense_features_2/Code_Metal_embedding/None_Lookup/LookupTableFindV2: target/dense_features_2/Code_Metal_embedding/None_Lookup/LookupTableFindV2:0
# Cannot infer shape for target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GreaterEqual: target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GreaterEqual:0
# Cannot infer shape for target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_2: target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_2:0
# (ir_version: 7
#  producer_name: "tf2onnx"
#  producer_version: "1.13.0 2c1db5"
#  graph {
#    node {
#      input: "teta_moy_v1r1"
#      input: "const_fold_opt__672"
#      output: "target/dense_features_2/teta_moy_v1r1/ExpandDims:0"
#      name: "target/dense_features_2/teta_moy_v1r1/ExpandDims"
#      op_type: "Unsqueeze"
#    }
#    node {
#      input: "target/dense_features_2/teta_moy_v1r1/ExpandDims:0"
#      input: "target/dense_features_2/teta_moy_v1r1/sub/y:0"
#      output: "target/dense_features_2/teta_moy_v1r1/sub:0"
#      name: "target/dense_features_2/teta_moy_v1r1/sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "Tps_Entree_TCC_Sortie_R1V1"
#      input: "const_fold_opt__672"
#      output: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/ExpandDims:0"
#      name: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/ExpandDims"
#      op_type: "Unsqueeze"
#    }
#    node {
#      input: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/ExpandDims:0"
#      input: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/sub/y:0"
#      output: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/sub:0"
#      name: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "R1V1_Taux_reduction_epaisseur"
#      input: "const_fold_opt__672"
#      output: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/ExpandDims:0"
#      name: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/ExpandDims"
#      op_type: "Unsqueeze"
#    }
#    node {
#      input: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/ExpandDims:0"
#      input: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/sub/y:0"
#      output: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/sub:0"
#      name: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "R1V1_Refoulement"
#      input: "const_fold_opt__672"
#      output: "target/dense_features_2/R1V1_Refoulement/ExpandDims:0"
#      name: "target/dense_features_2/R1V1_Refoulement/ExpandDims"
#      op_type: "Unsqueeze"
#    }
#    node {
#      input: "target/dense_features_2/R1V1_Refoulement/ExpandDims:0"
#      input: "target/dense_features_2/R1V1_Refoulement/sub/y:0"
#      output: "target/dense_features_2/R1V1_Refoulement/sub:0"
#      name: "target/dense_features_2/R1V1_Refoulement/sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "Longueur_Brame"
#      input: "const_fold_opt__672"
#      output: "target/dense_features_2/Longueur_Brame/ExpandDims:0"
#      name: "target/dense_features_2/Longueur_Brame/ExpandDims"
#      op_type: "Unsqueeze"
#    }
#    node {
#      input: "target/dense_features_2/Longueur_Brame/ExpandDims:0"
#      input: "target/dense_features_2/Longueur_Brame/sub/y:0"
#      output: "target/dense_features_2/Longueur_Brame/sub:0"
#      name: "target/dense_features_2/Longueur_Brame/sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "LARG_BRAME_THEOR"
#      input: "const_fold_opt__672"
#      output: "target/dense_features_2/LARG_BRAME_THEOR/ExpandDims:0"
#      name: "target/dense_features_2/LARG_BRAME_THEOR/ExpandDims"
#      op_type: "Unsqueeze"
#    }
#    node {
#      input: "target/dense_features_2/LARG_BRAME_THEOR/ExpandDims:0"
#      input: "target/dense_features_2/LARG_BRAME_THEOR/sub/y:0"
#      output: "target/dense_features_2/LARG_BRAME_THEOR/sub:0"
#      name: "target/dense_features_2/LARG_BRAME_THEOR/sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "target/dense_features_2/teta_moy_v1r1/sub:0"
#      input: "ConstantFolding/target/dense_features_2/teta_moy_v1r1/truediv_recip:0"
#      output: "target/dense_features_2/teta_moy_v1r1/truediv:0"
#      name: "target/dense_features_2/teta_moy_v1r1/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "target/dense_features_2/teta_moy_v1r1/truediv:0"
#      input: "target/dense_features_2/R1V1_Refoulement/Reshape_shape__676"
#      output: "target/dense_features_2/teta_moy_v1r1/Reshape:0"
#      name: "target/dense_features_2/teta_moy_v1r1/Reshape"
#      op_type: "Reshape"
#    }
#    node {
#      input: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/sub:0"
#      input: "ConstantFolding/target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/truediv_recip:0"
#      output: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/truediv:0"
#      name: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/truediv:0"
#      input: "target/dense_features_2/R1V1_Refoulement/Reshape_shape__676"
#      output: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/Reshape:0"
#      name: "target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/Reshape"
#      op_type: "Reshape"
#    }
#    node {
#      input: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/sub:0"
#      input: "ConstantFolding/target/dense_features_2/R1V1_Taux_reduction_epaisseur/truediv_recip:0"
#      output: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/truediv:0"
#      name: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/truediv:0"
#      input: "target/dense_features_2/R1V1_Refoulement/Reshape_shape__676"
#      output: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/Reshape:0"
#      name: "target/dense_features_2/R1V1_Taux_reduction_epaisseur/Reshape"
#      op_type: "Reshape"
#    }
#    node {
#      input: "target/dense_features_2/R1V1_Refoulement/sub:0"
#      input: "ConstantFolding/target/dense_features_2/R1V1_Refoulement/truediv_recip:0"
#      output: "target/dense_features_2/R1V1_Refoulement/truediv:0"
#      name: "target/dense_features_2/R1V1_Refoulement/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "target/dense_features_2/R1V1_Refoulement/truediv:0"
#      input: "target/dense_features_2/R1V1_Refoulement/Reshape_shape__676"
#      output: "target/dense_features_2/R1V1_Refoulement/Reshape:0"
#      name: "target/dense_features_2/R1V1_Refoulement/Reshape"
#      op_type: "Reshape"
#    }
#    node {
#      input: "target/dense_features_2/Longueur_Brame/sub:0"
#      input: "ConstantFolding/target/dense_features_2/Longueur_Brame/truediv_recip:0"
#      output: "target/dense_features_2/Longueur_Brame/truediv:0"
#      name: "target/dense_features_2/Longueur_Brame/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "target/dense_features_2/Longueur_Brame/truediv:0"
#      input: "target/dense_features_2/R1V1_Refoulement/Reshape_shape__676"
#      output: "target/dense_features_2/Longueur_Brame/Reshape:0"
#      name: "target/dense_features_2/Longueur_Brame/Reshape"
#      op_type: "Reshape"
#    }
#    node {
#      input: "target/dense_features_2/LARG_BRAME_THEOR/sub:0"
#      input: "ConstantFolding/target/dense_features_2/LARG_BRAME_THEOR/truediv_recip:0"
#      output: "target/dense_features_2/LARG_BRAME_THEOR/truediv:0"
#      name: "target/dense_features_2/LARG_BRAME_THEOR/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "target/dense_features_2/LARG_BRAME_THEOR/truediv:0"
#      input: "target/dense_features_2/R1V1_Refoulement/Reshape_shape__676"
#      output: "target/dense_features_2/LARG_BRAME_THEOR/Reshape:0"
#      name: "target/dense_features_2/LARG_BRAME_THEOR/Reshape"
#      op_type: "Reshape"
#    }
#    node {
#      input: "Code_Metal"
#      input: "const_fold_opt__672"
#      output: "target/dense_features_2/Code_Metal_embedding/ExpandDims:0"
#      name: "target/dense_features_2/Code_Metal_embedding/ExpandDims"
#      op_type: "Unsqueeze"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/ExpandDims:0"
#      output: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/dense_shape:0"
#      name: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/dense_shape"
#      op_type: "Shape"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/dense_shape:0"
#      input: "const_axes__387"
#      input: "const_ends__445"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Slice:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Slice"
#      op_type: "Slice"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Slice:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Prod:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Prod"
#      op_type: "ReduceProd"
#      attribute {
#        name: "axes"
#        ints: 0
#        type: INTS
#      }
#      attribute {
#        name: "keepdims"
#        i: 0
#        type: INT
#      }
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Prod:0"
#      input: "const_axes__387"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Unsqueeze__447:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Unsqueeze__447"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/dense_shape:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2/indices:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2"
#      op_type: "Gather"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2:0"
#      input: "const_axes__387"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Unsqueeze__449:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Unsqueeze__449"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Unsqueeze__447:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Unsqueeze__449:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Concat__450:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Concat__450"
#      op_type: "Concat"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Concat__450:0"
#      output: "ReduceProd__463:0"
#      name: "ReduceProd__463"
#      op_type: "ReduceProd"
#      attribute {
#        name: "axes"
#        ints: 0
#        type: INTS
#      }
#      attribute {
#        name: "keepdims"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Concat__450:0"
#      input: "cosnt_zero__466"
#      output: "Less__468:0"
#      name: "Less__468"
#      op_type: "Less"
#      domain: ""
#    }
#    node {
#      input: "lower_tri_const__470"
#      input: "cosnt_one__467"
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/dense_shape:0"
#      output: "Where__471:0"
#      name: "Where__471"
#      op_type: "Where"
#      domain: ""
#    }
#    node {
#      input: "Where__471:0"
#      output: "ReduceProd__472:0"
#      name: "ReduceProd__472"
#      op_type: "ReduceProd"
#      attribute {
#        name: "axes"
#        ints: 1
#        type: INTS
#      }
#      attribute {
#        name: "keepdims"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/dense_shape:0"
#      output: "ReduceProd__462:0"
#      name: "ReduceProd__462"
#      op_type: "ReduceProd"
#      attribute {
#        name: "axes"
#        ints: 0
#        type: INTS
#      }
#      attribute {
#        name: "keepdims"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "ReduceProd__462:0"
#      input: "ReduceProd__463:0"
#      output: "Div__464:0"
#      name: "Div__464"
#      op_type: "Div"
#      domain: ""
#    }
#    node {
#      input: "Div__464:0"
#      output: "Neg__465:0"
#      name: "Neg__465"
#      op_type: "Neg"
#      domain: ""
#    }
#    node {
#      input: "Less__468:0"
#      input: "Neg__465:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Cast/x_Concat__450:0"
#      output: "Where__469:0"
#      name: "Where__469"
#      op_type: "Where"
#      domain: ""
#    }
#    node {
#      input: "lower_tri_const__470"
#      input: "cosnt_one__467"
#      input: "Where__469:0"
#      output: "Where__474:0"
#      name: "Where__474"
#      op_type: "Where"
#      domain: ""
#    }
#    node {
#      input: "Where__474:0"
#      output: "ReduceProd__475:0"
#      name: "ReduceProd__475"
#      op_type: "ReduceProd"
#      attribute {
#        name: "axes"
#        ints: 1
#        type: INTS
#      }
#      attribute {
#        name: "keepdims"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "Where__469:0"
#      input: "const_axes__387"
#      input: "const_ends__445"
#      input: "const_axes__387"
#      output: "Slice__498:0"
#      name: "Slice__498"
#      op_type: "Slice"
#      domain: ""
#    }
#    node {
#      input: "Slice__498:0"
#      input: "const_axes__387"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Squeeze__510:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Squeeze__510"
#      op_type: "Squeeze"
#      domain: ""
#    }
#    node {
#      input: "cosnt_zero__466"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Squeeze__510:0"
#      input: "cosnt_one__467"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Range__511:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Range__511"
#      op_type: "Range"
#      domain: ""
#    }
#    node {
#      input: "Slice__498:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ConstantOfShape__499:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ConstantOfShape__499"
#      op_type: "ConstantOfShape"
#      attribute {
#        name: "value"
#        t {
#          dims: 1
#          data_type: 9
#          int32_data: 1
#          name: "value"
#        }
#        type: TENSOR
#      }
#      domain: ""
#    }
#    node {
#      input: "ReduceProd__462:0"
#      input: "ReduceProd__475:0"
#      output: "Concat__476:0"
#      name: "Concat__476"
#      op_type: "Concat"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "Concat__476:0"
#      input: "pad_const__477"
#      output: "Pad__478:0"
#      name: "Pad__478"
#      op_type: "Pad"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/ExpandDims:0"
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/ignore_value/x:0"
#      output: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/NotEqual:0"
#      name: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/NotEqual"
#      op_type: "Equal"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/NotEqual:0"
#      output: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/NotEqual__453:0"
#      name: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/NotEqual__453"
#      op_type: "Not"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/NotEqual__453:0"
#      output: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/indices:0"
#      name: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/indices"
#      op_type: "NonZero"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/indices:0"
#      output: "where_op_added__455:0"
#      name: "where_op_added__455"
#      op_type: "Transpose"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/ExpandDims:0"
#      input: "where_op_added__455:0"
#      output: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/values:0"
#      name: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/values"
#      op_type: "GatherND"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/to_sparse_input/values:0"
#      output: "target/dense_features_2/Code_Metal_embedding/None_Lookup/LookupTableFindV2:0"
#      name: "target/dense_features_2/Code_Metal_embedding/None_Lookup/LookupTableFindV2"
#      op_type: "CategoryMapper"
#      attribute {
#        name: "cats_int64s"
#        ints: 23
#        ints: 10
#        ints: 4
#        ints: 22
#        ints: 30
#        ints: 14
#        ints: 41
#        ints: 11
#        ints: 19
#        ints: 40
#        ints: 25
#        ints: 31
#        ints: 2
#        ints: 12
#        ints: 18
#        ints: 37
#        ints: 0
#        ints: 17
#        ints: 21
#        ints: 15
#        ints: 8
#        ints: 13
#        ints: 39
#        ints: 33
#        ints: 20
#        ints: 27
#        ints: 35
#        ints: 7
#        ints: 24
#        ints: 32
#        ints: 28
#        ints: 1
#        ints: 26
#        ints: 29
#        ints: 9
#        ints: 6
#        ints: 5
#        ints: 16
#        ints: 36
#        ints: 34
#        ints: 3
#        ints: 38
#        type: INTS
#      }
#      attribute {
#        name: "cats_strings"
#        strings: "30"
#        strings: "33"
#        strings: "40"
#        strings: "6"
#        strings: "12"
#        strings: "11"
#        strings: "20"
#        strings: "5"
#        strings: "2"
#        strings: "52"
#        strings: "36"
#        strings: "53"
#        strings: "1"
#        strings: "62"
#        strings: "22"
#        strings: "70"
#        strings: "32"
#        strings: "42"
#        strings: "8"
#        strings: "14"
#        strings: "45"
#        strings: "61"
#        strings: "51"
#        strings: "65"
#        strings: "13"
#        strings: "34"
#        strings: "90"
#        strings: "48"
#        strings: "35"
#        strings: "50"
#        strings: "3"
#        strings: "31"
#        strings: "10"
#        strings: "71"
#        strings: "43"
#        strings: "47"
#        strings: "41"
#        strings: "63"
#        strings: "9"
#        strings: "81"
#        strings: "4"
#        strings: "21"
#        type: STRINGS
#      }
#      attribute {
#        name: "default_int64"
#        i: -1
#        type: INT
#      }
#      domain: "ai.onnx.ml"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/None_Lookup/LookupTableFindV2:0"
#      input: "cosnt_zero__466"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GreaterEqual:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GreaterEqual"
#      op_type: "GreaterOrEqual"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GreaterEqual:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Where:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Where"
#      op_type: "NonZero"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Where:0"
#      output: "where_op_added__458:0"
#      name: "where_op_added__458"
#      op_type: "Transpose"
#    }
#    node {
#      input: "where_op_added__458:0"
#      input: "const_fold_opt__672"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Reshape:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Reshape"
#      op_type: "Reshape"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/None_Lookup/LookupTableFindV2:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Reshape:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_2:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_2"
#      op_type: "Gather"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#    }
#    node {
#      input: "where_op_added__455:0"
#      input: "ReduceProd__472:0"
#      output: "MatMul__479:0"
#      name: "MatMul__479"
#      op_type: "MatMul"
#      domain: ""
#    }
#    node {
#      input: "MatMul__479:0"
#      input: "const_ends__445"
#      output: "Unsqueeze__482:0"
#      name: "Unsqueeze__482"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "Unsqueeze__482:0"
#      input: "Pad__478:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseReshape_Mod__484:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseReshape_Mod__484"
#      op_type: "Mod"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseReshape_Mod__484:0"
#      input: "ReduceProd__475:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseReshape_Div__486:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseReshape_Div__486"
#      op_type: "Div"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseReshape_Div__486:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Reshape:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_1:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_1"
#      op_type: "Gather"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_1:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__520:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__520"
#      op_type: "Shape"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__520:0"
#      input: "const_ends__445"
#      input: "const_ends__523"
#      input: "const_axes__387"
#      output: "Slice__525:0"
#      name: "Slice__525"
#      op_type: "Slice"
#      domain: ""
#    }
#    node {
#      input: "Slice__525:0"
#      input: "cosnt_one__467"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Sub__526:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Sub__526"
#      op_type: "Sub"
#      domain: ""
#    }
#    node {
#      input: "triple_0__527"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Sub__526:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__528:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__528"
#      op_type: "Concat"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_1:0"
#      input: "const_axes__387"
#      input: "const_ends__445"
#      input: "const_ends__445"
#      output: "Slice__491:0"
#      name: "Slice__491"
#      op_type: "Slice"
#      domain: ""
#    }
#    node {
#      input: "Slice__491:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Unique__493:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Unique__493"
#      op_type: "Unique"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Unique__493:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__500:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__500"
#      op_type: "Shape"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__500:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ConstantOfShape__502:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ConstantOfShape__502"
#      op_type: "ConstantOfShape"
#      attribute {
#        name: "value"
#        t {
#          dims: 1
#          data_type: 9
#          int32_data: 0
#          name: "value"
#        }
#        type: TENSOR
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ConstantOfShape__499:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Unique__493:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ConstantOfShape__502:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ScatterElements__503:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ScatterElements__503"
#      op_type: "ScatterElements"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Range__511:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ScatterElements__503:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Compress__512:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Compress__512"
#      op_type: "Compress"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Compress__512:0"
#      input: "const_ends__445"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Unsqueeze__516:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Unsqueeze__516"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Unsqueeze__516:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__528:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Pad__529:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Pad__529"
#      op_type: "Pad"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_1:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Pad__529:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__530:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__530"
#      op_type: "Concat"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__530:0"
#      input: "const_starts__533"
#      input: "const_ends__534"
#      input: "const_axes__535"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/strided_slice:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/strided_slice"
#      op_type: "Slice"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/strided_slice:0"
#      input: "const_ends__445"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/strided_slice__536:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/strided_slice__536"
#      op_type: "Squeeze"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/strided_slice__536:0"
#      output: "Shape__549:0"
#      name: "Shape__549"
#      op_type: "Shape"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/strided_slice__536:0"
#      input: "Shape__549:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_TopK__553:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_TopK__553:1"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_TopK__553"
#      op_type: "TopK"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      attribute {
#        name: "largest"
#        i: 0
#        type: INT
#      }
#      attribute {
#        name: "sorted"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_TopK__553:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555:0"
#      output: ""
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555:2"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555:3"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555"
#      op_type: "Unique"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      attribute {
#        name: "sorted"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555:3"
#      output: "ReduceMax__557:0"
#      name: "ReduceMax__557"
#      op_type: "ReduceMax"
#      attribute {
#        name: "axes"
#        ints: 0
#        type: INTS
#      }
#      attribute {
#        name: "keepdims"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555:3"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555:2"
#      output: "Gather__569:0"
#      name: "Gather__569"
#      op_type: "Gather"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_TopK__553:0"
#      input: "const_fold_opt__672"
#      output: "Unsqueeze__578:0"
#      name: "Unsqueeze__578"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "Shape__549:0"
#      input: "const_axes__387"
#      output: "Squeeze__552:0"
#      name: "Squeeze__552"
#      op_type: "Squeeze"
#      domain: ""
#    }
#    node {
#      input: "cosnt_zero__466"
#      input: "Squeeze__552:0"
#      input: "cosnt_one__467"
#      output: "Range__568:0"
#      name: "Range__568"
#      op_type: "Range"
#      domain: ""
#    }
#    node {
#      input: "Range__568:0"
#      input: "Gather__569:0"
#      output: "Mod__572:0"
#      name: "Mod__572"
#      op_type: "Mod"
#      domain: ""
#    }
#    node {
#      input: "Mod__572:0"
#      input: "const_fold_opt__672"
#      output: "Unsqueeze__581:0"
#      name: "Unsqueeze__581"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "Unsqueeze__578:0"
#      input: "Unsqueeze__581:0"
#      output: "Concat__583:0"
#      name: "Concat__583"
#      op_type: "Concat"
#      attribute {
#        name: "axis"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/strided_slice__536:0"
#      output: "ReduceMax__543:0"
#      name: "ReduceMax__543"
#      op_type: "ReduceMax"
#      attribute {
#        name: "axes"
#        ints: 0
#        type: INTS
#      }
#      attribute {
#        name: "keepdims"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Compress__512:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__517:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__517"
#      op_type: "Shape"
#      domain: ""
#    }
#    node {
#      input: "cosnt_zero__466"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Shape__517:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Expand__518:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Expand__518"
#      op_type: "Expand"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/GatherV2_2:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Expand__518:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__532:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__532"
#      op_type: "Concat"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_Concat__532:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique:1"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique:2"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique"
#      op_type: "Unique"
#      attribute {
#        name: "sorted"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/ReadVariableOp:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/embedding_lookup:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/embedding_lookup"
#      op_type: "Gather"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique:2"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique__538_cast:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique__538_cast"
#      op_type: "Cast"
#      attribute {
#        name: "to"
#        i: 6
#        type: INT
#      }
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/embedding_lookup:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse/Unique__538_cast:0"
#      output: "Gather__540:0"
#      name: "Gather__540"
#      op_type: "Gather"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "Gather__540:0"
#      output: "Shape__591:0"
#      name: "Shape__591"
#      op_type: "Shape"
#      domain: ""
#    }
#    node {
#      input: "Shape__591:0"
#      input: "const_ends__445"
#      input: "const_ends__594"
#      input: "const_axes__387"
#      output: "Slice__596:0"
#      name: "Slice__596"
#      op_type: "Slice"
#      domain: ""
#    }
#    node {
#      input: "Slice__596:0"
#      output: "ConstantOfShape__597:0"
#      name: "ConstantOfShape__597"
#      op_type: "ConstantOfShape"
#      attribute {
#        name: "value"
#        t {
#          dims: 1
#          data_type: 1
#          float_data: 0.0
#          name: "value"
#        }
#        type: TENSOR
#      }
#      domain: ""
#    }
#    node {
#      input: "ConstantOfShape__597:0"
#      input: "const_axes__387"
#      output: "Unsqueeze__599:0"
#      name: "Unsqueeze__599"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "Gather__540:0"
#      input: "Unsqueeze__599:0"
#      output: "Concat__601:0"
#      name: "Concat__601"
#      op_type: "Concat"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/SparseFillEmptyRows/SparseFillEmptyRows_ScatterElements__503:0"
#      input: "target/dense_features_2/R1V1_Refoulement/Reshape_shape__676"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Reshape_1:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Reshape_1"
#      op_type: "Reshape"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Reshape_1:0"
#      input: "const_fold_opt__664"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Tile:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Tile"
#      op_type: "Tile"
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Tile:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__624:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__624"
#      op_type: "Not"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__624:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__626:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__626"
#      op_type: "Cast"
#      attribute {
#        name: "to"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/Tile:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__622:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__622"
#      op_type: "Cast"
#      attribute {
#        name: "to"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "ReduceMax__543:0"
#      input: "cosnt_one__467"
#      output: "Add__546:0"
#      name: "Add__546"
#      op_type: "Add"
#      domain: ""
#    }
#    node {
#      input: "Add__546:0"
#      input: "const_axes__387"
#      output: "Unsqueeze__548:0"
#      name: "Unsqueeze__548"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "Unsqueeze__548:0"
#      output: "ConstantOfShape__559:0"
#      name: "ConstantOfShape__559"
#      op_type: "ConstantOfShape"
#      attribute {
#        name: "value"
#        t {
#          dims: 1
#          data_type: 7
#          int64_data: 0
#          name: "value"
#        }
#        type: TENSOR
#      }
#      domain: ""
#    }
#    node {
#      input: "ConstantOfShape__559:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_Unique__555:3"
#      output: "ScatterElements__560:0"
#      name: "ScatterElements__560"
#      op_type: "ScatterElements"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "ScatterElements__560:0"
#      output: "Cast__564:0"
#      name: "Cast__564"
#      op_type: "Cast"
#      attribute {
#        name: "to"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "Cast__564:0"
#      input: "const_ends__445"
#      output: "Unsqueeze__613:0"
#      name: "Unsqueeze__613"
#      op_type: "Unsqueeze"
#      domain: ""
#    }
#    node {
#      input: "Unsqueeze__548:0"
#      input: "ReduceMax__557:0"
#      output: "Concat__575:0"
#      name: "Concat__575"
#      op_type: "Concat"
#      attribute {
#        name: "axis"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "Concat__575:0"
#      output: "ConstantOfShape__576:0"
#      name: "ConstantOfShape__576"
#      op_type: "ConstantOfShape"
#      attribute {
#        name: "value"
#        t {
#          dims: 1
#          data_type: 7
#          int64_data: -1
#          name: "value"
#        }
#        type: TENSOR
#      }
#      domain: ""
#    }
#    node {
#      input: "ConstantOfShape__576:0"
#      input: "Concat__583:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_TopK__553:1"
#      output: "ScatterND__586:0"
#      name: "ScatterND__586"
#      op_type: "ScatterND"
#      domain: ""
#    }
#    node {
#      input: "Concat__601:0"
#      input: "ScatterND__586:0"
#      output: "Gather__604:0"
#      name: "Gather__604"
#      op_type: "Gather"
#      domain: ""
#    }
#    node {
#      input: "Gather__604:0"
#      input: "const_ends__445"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_ReduceSum__609:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_ReduceSum__609"
#      op_type: "ReduceSum"
#      attribute {
#        name: "keepdims"
#        i: 0
#        type: INT
#      }
#      attribute {
#        name: "noop_with_empty_axes"
#        i: 0
#        type: INT
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/embedding_lookup_sparse_ReduceSum__609:0"
#      input: "Unsqueeze__613:0"
#      output: "Div__615:0"
#      name: "Div__615"
#      op_type: "Div"
#      domain: ""
#    }
#    node {
#      input: "Div__615:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__626:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__632:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__632"
#      op_type: "Mul"
#      domain: ""
#    }
#    node {
#      input: "Div__615:0"
#      output: "Shape__618:0"
#      name: "Shape__618"
#      op_type: "Shape"
#      domain: ""
#    }
#    node {
#      input: "Shape__618:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/zeros_like:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/zeros_like"
#      op_type: "ConstantOfShape"
#      attribute {
#        name: "value"
#        t {
#          dims: 1
#          data_type: 1
#          float_data: 0.0
#          name: "value"
#        }
#        type: TENSOR
#      }
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__622:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights/zeros_like:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__628:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__628"
#      op_type: "Mul"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__628:0"
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights__632:0"
#      output: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights:0"
#      name: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_weights"
#      op_type: "Add"
#      domain: ""
#    }
#    node {
#      input: "target/dense_features_2/Code_Metal_embedding/Code_Metal_embedding_we
#      raw_data: "\000\000\000\000\000\000\000\000\377\377\377\377\377\377\377\377"
#    }
#    initializer {
#      dims: 2
#      dims: 2
#      data_type: 9
#      name: "lower_tri_const__470"
#      raw_data: "\001\000\001\001"
#    }
#    initializer {
#      data_type: 7
#      name: "cosnt_zero__466"
#      raw_data: "\000\000\000\000\000\000\000\000"
#    }
#    initializer {
#      data_type: 7
#      name: "cosnt_one__467"
#      raw_data: "\001\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 2
#      data_type: 7
#      name: "const_starts__533"
#      raw_data: "\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 1
#      data_type: 7
#      name: "const_fold_opt__672"
#      raw_data: "\377\377\377\377\377\377\377\377"
#    }
#    initializer {
#      dims: 2
#      data_type: 7
#      name: "const_fold_opt__664"
#      raw_data: "\001\000\000\000\000\000\000\0002\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 1
#      data_type: 7
#      name: "const_ends__594"
#      raw_data: "\377\377\377\377\377\377\377\177"
#    }
#    initializer {
#      dims: 2
#      data_type: 7
#      name: "const_ends__534"
#      raw_data: "\377\377\377\177\000\000\000\000\001\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 1
#      data_type: 7
#      name: "const_ends__523"
#      raw_data: "\002\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 1
#      data_type: 7
#      name: "const_ends__445"
#      raw_data: "\001\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 2
#      data_type: 7
#      name: "const_axes__535"
#      raw_data: "\000\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000"
#    }
#    initializer {
#      dims: 1
#      data_type: 7
#      name: "const_axes__387"
#      raw_data: "\000\000\000\000\000\000\000\000"
#    }
#    initializer {
#      data_type: 1
#      name: "ConstantFolding/target/dense_features_2/teta_moy_v1r1/truediv_recip:0"
#      raw_data: "a`\251;"
#    }
#    initializer {
#      data_type: 1
#      name: "ConstantFolding/target/dense_features_2/Tps_Entree_TCC_Sortie_R1V1/truediv_recip:0"
#      raw_data: "\354\016\027<"
#    }
#    initializer {
#      data_type: 1
#      name: "ConstantFolding/target/dense_features_2/R1V1_Taux_reduction_epaisseur/truediv_recip:0"
#      raw_data: "q\376G="
#    }
#    initializer {
#      data_type: 1
#      name: "ConstantFolding/target/dense_features_2/R1V1_Refoulement/truediv_recip:0"
#      raw_data: "\246\251j;"
#    }
#    initializer {
#      data_type: 1
#      name: "ConstantFolding/target/dense_features_2/Longueur_Brame/truediv_recip:0"
#      raw_data: "\216\260\\>"
#    }
#    initializer {
#      data_type: 1
#      name: "ConstantFolding/target/dense_features_2/LARG_BRAME_THEOR/truediv_recip:0"
#      raw_data: "I\226_:"
#    }
#    doc_string: "converted from target"
#    input {
#      name: "Code_Metal"
#      type {
#        tensor_type {
#          elem_type: 8
#          shape {
#            dim {
#              dim_param: "unk__682"
#            }
#          }
#        }
#      }
#    }
#    input {
#      name: "DK_TCC_Laminoir_R1V1_IPE_ELEC_EN_CHARGE_kWh_BOB"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__683"
#            }
#          }
#        }
#      }
#    }
#    input {
#      name: "LARG_BRAME_THEOR"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__684"
#            }
#          }
#        }
#      }
#    }
#    input {
#      name: "Longueur_Brame"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__685"
#            }
#          }
#        }
#      }
#    }
#    input {
#      name: "R1V1_Refoulement"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__686"
#            }
#          }
#        }
#      }
#    }
#    input {
#      name: "R1V1_Taux_reduction_epaisseur"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__687"
#            }
#          }
#        }
#      }
#    }
#    input {
#      name: "Tps_Entree_TCC_Sortie_R1V1"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__688"
#            }
#          }
#        }
#      }
#    }
#    input {
#      name: "teta_moy_v1r1"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__689"
#            }
#          }
#        }
#      }
#    }
#    output {
#      name: "output_1"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__690"
#            }
#            dim {
#              dim_value: 1
#            }
#          }
#        }
#      }
#    }
#  }
#  opset_import {
#    domain: ""
#    version: 13
#  }
#  opset_import {
#    domain: "ai.onnx.ml"
#    version: 2
#  },
#  None)

# %%
formula = '[model] '

for tag in dico_model['facteurs'].keys():
    if dico_model['facteurs'][tag]['used']:
        if dico_model['facteurs'][tag]['type'] == 'num':
            nom_feat = dico_model['facteurs'][tag]['nom']
            min_val = str(data[nom_feat].min())
            max_val = str(data[nom_feat].max())
            formula = formula + " .Arg(" + '"' + nom_feat +'"'+ ", [" + tag + "]"
            formula = formula + ", " + min_val + ", " + max_val +  ")"

        elif dico_model['facteurs'][tag]['type'] == 'cat':
            nom_feat = dico_model['facteurs'][tag]['nom']
            mod_liste = list(data[nom_feat].unique())
            mod_liste = '","'.join(map(str,mod_liste))
            mod_liste = '"'+mod_liste+'"'
            formula = formula + " .Arg(" + '"' + nom_feat +'"'+ ", [" + tag + "]"
            formula = formula + ", " +mod_liste +  ")"


formula = formula + " .Outputs(" + '"' + 'target' + '"' + ")"

# %%
formula
# Out:
# '[model]  .Arg("R1V1_Taux_reduction_epaisseur", [tag_10260], 8.496718988185847, 28.977342970827657) .Arg("R1V1_Refoulement", [tag_10261], 0.0, 301.874572753906) .Arg("Tps_Entree_TCC_Sortie_R1V1", [tag_35633], 22.24892807006837, 130.7103796005249) .Arg("LARG_BRAME_THEOR", [tag_3931], 750.0, 1922.44714355469) .Arg("teta_moy_v1r1", [tag_9323], 1100.06127929688, 1293.52380371094) .Arg("Longueur_Brame", [tag_3928], 5.21, 9.85) .Arg("Code_Metal", [tag_3359], "32","31","1","4","40","41","47","48","45","43","33","5","62","61","11","14","63","42","22","2","13","8","6","30","35","36","10","34","3","71","12","53","50","65","81","90","9","70","21","51","52","20") .Outputs("target")'
